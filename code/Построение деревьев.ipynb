# %%
import matplotlib.pyplot as plt
from Bio import Phylo

file_path = r"C:\Users\rusla\OneDrive\Рабочий стол\tree_with_bootstrap.nwk"
tree = Phylo.read(file_path, "newick")

fig, ax = plt.subplots(figsize=(20, 14))
Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
ax.set_xlim(0.02, 0.02)
ax.set_ylim(0, 100)  # Настройка лимитов оси y

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 8
#       5 tree = Phylo.read(file_path, "newick")
#       7 fig, ax = plt.subplots(figsize=(20, 14))
# ----> 8 Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
#       9 ax.set_xlim(0.02, 0.02)
#      10 ax.set_ylim(0, 100)  # Настройка лимитов оси y
#
# File c:\Users\rusla\AppData\Local\Programs\Python\Python312\Lib\site-packages\Bio\Phylo\_utils.py:591, in draw(tree, label_func, do_show, show_confidence, axes, branch_labels, label_colors, *args, **kwargs)
#     589     list(value)
#     590 except TypeError:
# --> 591     raise ValueError(
#     592         'Keyword argument "%s=%s" is not in the format '
#     593         "pyplot_option_name=(tuple), pyplot_option_name=(tuple, dict),"
#     594         " or pyplot_option_name=(dict) " % (key, value)
#     595     ) from None
# ...

# %%
import matplotlib.pyplot as plt
from Bio import Phylo

file_path = r"C:\Users\rusla\OneDrive\Рабочий стол\tree_with_bootstrap.nwk"
tree = Phylo.read(file_path, "newick")

fig, ax = plt.subplots(figsize=(20, 14))
Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
ax.set_xlim(0.02, 0.02)
ax.set_ylim(0, 100)  # Настройка лимитов оси y

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 8
#       5 tree = Phylo.read(file_path, "newick")
#       7 fig, ax = plt.subplots(figsize=(20, 14))
# ----> 8 Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
#       9 ax.set_xlim(0.02, 0.02)
#      10 ax.set_ylim(0, 100)  # Настройка лимитов оси y
#
# File c:\Users\rusla\AppData\Local\Programs\Python\Python312\Lib\site-packages\Bio\Phylo\_utils.py:591, in draw(tree, label_func, do_show, show_confidence, axes, branch_labels, label_colors, *args, **kwargs)
#     589     list(value)
#     590 except TypeError:
# --> 591     raise ValueError(
#     592         'Keyword argument "%s=%s" is not in the format '
#     593         "pyplot_option_name=(tuple), pyplot_option_name=(tuple, dict),"
#     594         " or pyplot_option_name=(dict) " % (key, value)
#     595     ) from None
# ...

# %%
import matplotlib.pyplot as plt
from Bio import Phylo

file_path = r"C:\Users\rusla\OneDrive\Рабочий стол\tree_with_bootstrap_updated.nwk"
tree = Phylo.read(file_path, "newick")

fig, ax = plt.subplots(figsize=(20, 14))
Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
ax.set_xlim(0.02, 0.02)
ax.set_ylim(0, 100)  # Настройка лимитов оси y

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 8
#       5 tree = Phylo.read(file_path, "newick")
#       7 fig, ax = plt.subplots(figsize=(20, 14))
# ----> 8 Phylo.draw(tree, axes=ax, label_offset=0.02, branch_labels=False)
#       9 ax.set_xlim(0.02, 0.02)
#      10 ax.set_ylim(0, 100)  # Настройка лимитов оси y
#
# File c:\Users\rusla\AppData\Local\Programs\Python\Python312\Lib\site-packages\Bio\Phylo\_utils.py:591, in draw(tree, label_func, do_show, show_confidence, axes, branch_labels, label_colors, *args, **kwargs)
#     589     list(value)
#     590 except TypeError:
# --> 591     raise ValueError(
#     592         'Keyword argument "%s=%s" is not in the format '
#     593         "pyplot_option_name=(tuple), pyplot_option_name=(tuple, dict),"
#     594         " or pyplot_option_name=(dict) " % (key, value)
#     595     ) from None
# ...
